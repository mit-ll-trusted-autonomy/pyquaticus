# %% [markdown]
# <a href="https://colab.research.google.com/github/j-horng/pyquaticus-dynamic2026/blob/connect-colab-to-github/colab-to-githhub-test.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("Testing connection")
# Out:
# Testing connection
